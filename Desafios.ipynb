# %% [markdown]
# ## **Primeiro Desafio - Colunas e barras**
#
# ---

# %% [markdown]
# Vamos praticar a criação de gráficos de comparação (colunas e barras) que aprendemos até aqui. Para a prática, vamos seguir utilizando o conjunto de dados do relatório de vendas das lojas de departamentos de 2016 a 2019 que está disponível no <a href = 'https://github.com/alura-cursos/dataviz-graficos/blob/master/dados/relatorio_vendas.csv'>github do projeto</a>.
#
# Neste desafio, a missão é construir as visualizações que respondam aos questionamentos que compartilharemos aqui abaixo:

# %%
# Importando bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
AZUL1, AZUL2, AZUL3, AZUL4, AZUL5 = '#03045e', '#0077b6', "#00b4d8", '#90e0ef', '#CDDBF3'
CINZA1, CINZA2, CINZA3, CINZA4, CINZA5 = '#212529', '#495057', '#adb5bd', '#dee2e6', '#f8f9fa'
VERMELHO1, LARANJA1, AMARELO1, VERDE1, VERDE2 = '#e76f51', '#f4a261',	'#e9c46a', '#4c956c', '#2a9d8f'

# %% [markdown]
# ###<b>Desafio 1:</b> Quais são os lucros das vendas por ano? Em qual ano obtivemos o maior lucro?

# %%
# Lendo os dados
url = '/content/drive/MyDrive/Data Science/Data Visualization/Gráf.de comp.e distr/relatorio_vendas.csv'
vendas = pd.read_csv(url)
vendas.head()
# Out:
#   data_pedido  data_envio      modo_envio       nome_cliente segmento_cliente  \
# 0  2018-11-09  2018-11-12       Econômica    Thiago Silveira              B2C
# 1  2018-11-09  2018-11-12       Econômica    Thiago Silveira              B2C
# 2  2018-06-13  2018-06-17       Econômica      Giovanna Lima              B2B
# 3  2017-10-12  2017-10-19  Entrega padrão  Ana Júlia da Cruz              B2C
# 4  2017-10-12  2017-10-19  Entrega padrão  Ana Júlia da Cruz              B2C
#
#            cidade          estado   regiao             departamento  \
# 0  Ribeirão Preto       São Paulo  Sudeste  Materiais de construção
# 1  Ribeirão Preto       São Paulo  Sudeste  Materiais de construção
# 2  Rio de Janeiro  Rio de Janeiro  Sudeste  Jardinagem e paisagismo
# 3   Foz do Iguaçu          Paraná      Sul  Materiais de construção
# 4   Foz do Iguaçu          Paraná      Sul  Jardinagem e paisagismo
#
#                 tipo_produto  preco_base  preco_unit_sem_desc  desconto  \
# ...

# %%
# convertendo datas para o tipo datetime
vendas['data_pedido'] = pd.to_datetime(vendas['data_pedido'], format = '%Y-%m-%d')
vendas['data_envio'] = pd.to_datetime(vendas['data_envio'], format = '%Y-%m-%d')

# %%
# criando um novo dataset com os lucros por ano
lucro = vendas.copy() # criando uma cópia para criar dois dataframes independentes
lucro_ano = lucro.loc[:, ('data_pedido', 'lucro')] # se não usar o .loc(), o pandas reclama de estar buscando valores em uma cópia de um  dataframe
lucro_ano['ano'] = lucro_ano['data_pedido'].dt.year # extraindo apenas o ano de data_pedido e criando uma nova coluna com esses dados
lucro_ano.drop(labels = 'data_pedido', axis = 1, inplace = True) # removendo a coluna data_pedido, pois ela não será mais necessária
lucro_ano = lucro_ano.groupby('ano').sum() # somando todos os lucros por ano
lucro_ano # retornando o dataframe
# Out:
#           lucro
# ano
# 2016   75033.63
# 2017  101265.15
# 2018  129862.44
# 2019  148097.30

# %%
## Criando e definindo a área da figura
fig, ax = plt.subplots(figsize = (10,4))
fig.subplots_adjust(right = 0.7) # ajustando a figura
sns.set_theme(style = 'white', palette = None) # definindo um tema para a figura

cores = []
for ano in lucro_ano.index:
  if lucro_ano.loc[ano, 'lucro'] == lucro_ano.lucro.max():
    cores.append('blue')  # iterando em todos os anos, para que a coluna com o
  else:                      # maior lucro receba uma cor diferente no gráfico,
    cores.append('skyblue')   # com o objetivo da mesma ficar em destaque

ax = sns.barplot(data = lucro_ano, x = lucro_ano.index, y = 'lucro', palette = cores)

sns.despine(left = True, bottom = True) # removendo as bordas do gráfico
ax.set_title('Comparação do lucro por ano\n2016 a 2019', fontsize = 18, loc = 'left', color = '#495057') # definindo título
ax.set_xlabel('') # removendo as labels do eixo x
ax.set_ylabel('') # removendo labels do eixo y
ax.xaxis.set_tick_params(labelsize = 14, labelcolor = '#495057') # modificando os ticks do eixo x
ax.set_yticklabels([]) # removendo os ticks do eixo y

# Escrevendo o valor de cada coluna no gráfico
for i, valor in enumerate(lucro_ano['lucro']): # percorrendo cada ano e cada valor na coluna lucro
  qtd = f'R$ {valor:,.0f}' # printando o valor formatado
  offset = 1e4 # definindo o tamanho do número
  ax.text(i, valor + offset, qtd, color = '#495057', fontsize = 12, ha = 'center', va = 'center')

ax.text(3.5, 1e5,
        'O maior lucro registrado foi no ano $\\bf{2019}$.\n'
        'Em comparação com 2018, o lucro\n'
        'subiu aproximadamente $\\bf{14,04}$%.',
        fontsize=14, linespacing=1.45, color='#0077b6')
# Out:
# Text(3.5, 100000.0, 'O maior lucro registrado foi no ano $\\bf{2019}$.\nEm comparação com 2018, o lucro\nsubiu aproximadamente $\\bf{14,04}$%.')

# %% [markdown]
# ### **Desafio 2** - top faturamentos
#
# ___

# %% [markdown]
# **Qual foi o faturamento (vendas) dos top 10 produtos durante o período de 2016 a 2019 do nosso conjunto de dados? Adicione um pequeno texto falando dos 3 produtos que mais venderam.**

# %%
# precisarei de um dataframe somente com os dados das vendas por tipo de produto
produtos = vendas.copy()
produtos = vendas[['tipo_produto', 'vendas']]
produtos = produtos.groupby(['tipo_produto']).sum().sort_values('vendas', ascending = False)

# agora criarei um dataframe somente com o top 10 de vendas
top_10 = produtos[:10]
top_10
# Out:
#                                vendas
# tipo_produto
# pneus                      1022428.97
# ferramentas                 995158.41
# vasos                       696044.18
# ferramentas de jardinagem   648879.72
# materiais de revestimento   629656.36
# equipamentos de limpeza     542304.58
# ferramentas automotivas     502109.29
# peças de reposição          486907.94
# encanamentos                373223.88
# mobiliário de exterior      328932.27

# %%
from matplotlib import transforms

def texto_colorido(x, y, texto, cores, esp=20, ax = None, **kw):
  cores = list(reversed(cores))
  t = ax.transData
  canvas = ax.figure.canvas

  for i, linha in enumerate(reversed(texto.split('\n'))):
    frases = linha.split('||')
    for s, cor in zip(frases, cores[i]):
      texto = ax.text(x, y, s, color = cor, transform = t, **kw)
      texto.draw(canvas.get_renderer())
      ex = texto.get_window_extent()
      t = transforms.offset_copy(texto._transform, x = ex.width, units = 'dots')

    t = transforms.offset_copy(ax.transData, x = 0, y = (i + 1) * esp, units = 'dots')

# %%
fig, ax = plt.subplots(figsize = (10, 4))
fig.subplots_adjust(right = 0.7)
sns.set_theme(style = 'white')

cores = [AZUL2 if i < 3 else CINZA3 for i in range(10)]
ax = sns.barplot(data = top_10, x = 'vendas', y = top_10.index, palette = cores)

ax.set_title('Top 10 com maiores vendas no catálogo (2016-2019)\n', fontsize = 18, color = CINZA1, loc = 'left')
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_xticklabels([])
ax.yaxis.set_tick_params(labelsize = 10, labelcolor = CINZA2)
sns.despine(left = True, bottom = True)

for i, valor in enumerate(top_10['vendas']):
  qtd = f'R$ {valor:,.0f}'.replace(',', '.')
  offset = 1e4
  ax.text(valor - offset, i, qtd, color = CINZA5, fontsize = 10, fontweight = 'bold', ha = 'center', va = 'center')

texto_colorido(
    1.05e6, 4,
    'Os dados indicam que os 3 produtos que || $\\bf{mais}$\n'
    'venderam foram: || $\\bf{pneus, \ ferramentas\ e\ vasos}$.\n'
    '\n'
    'Podemos notar no período mencionado também que as\n'
    'ferramentas de jardinagem e materiais de revestimento\n'
    'também possuem uma boa saída.',
    [[CINZA2, CINZA1],
     [CINZA2, AZUL2],
     [CINZA2],
     [CINZA2],
     [CINZA2],
     [CINZA2]],
    esp = 22, ax = ax, fontsize = 10
)

plt.show()

# %% [markdown]
# ## **Segundo desafio - agrupando dados**
# ___

# %% [markdown]
# Vamos praticar a criação de gráficos de comparação representando os valores agrupados por colunas e/ou barras. Para esse desafio, vamos seguir utilizando o conjunto de dados do relatório de vendas das lojas de departamentos de 2016 a 2019 que está disponível no <a href = 'https://github.com/alura-cursos/dataviz-graficos/blob/master/dados/relatorio_vendas.csv'>github do projeto</a>.
#
# Neste desafio, a missão é construir as visualizações que respondam aos questionamentos abaixo:

# %% [markdown]
# ### **Desafio 1:** Como estão divididas as vendas das lojas de departamentos na Região Centro-Oeste nos anos de 2017 e 2018? O mesmo estado permaneceu como o que mais vendeu nesta região?

# %%
vendas.head(1)
# Out:
#   data_pedido data_envio modo_envio     nome_cliente segmento_cliente  \
# 0  2018-11-09 2018-11-12  Econômica  Thiago Silveira              B2C
#
#            cidade     estado   regiao             departamento  tipo_produto  \
# 0  Ribeirão Preto  São Paulo  Sudeste  Materiais de construção  encanamentos
#
#    preco_base  preco_unit_sem_desc  desconto  preco_unit_venda  quantidade  \
# 0       409.7               445.33       0.0            445.33           2
#
#    vendas  lucro
# 0  890.66  71.26

# %%
vendas_co = vendas.copy() # co = centro-oeste
vendas_co = vendas_co[['data_pedido', 'vendas', 'regiao', 'estado']]
vendas_co['ano'] = vendas_co['data_pedido'].dt.year # dt.year é nativo do pandas
vendas_co.drop(columns = 'data_pedido', axis = 1, inplace = True)
vendas_co = vendas_co.query("regiao == 'Centro-Oeste'")
vendas_co.reset_index(inplace = True, drop = True)
vendas_co.drop(columns = 'regiao', axis = 1, inplace = True)
vendas_co = pd.crosstab(index = vendas_co['ano'], columns = vendas_co['estado'], values = vendas_co['vendas'], aggfunc = 'sum')
vendas_co
# Out:
# estado  Distrito Federal     Goiás  Mato Grosso  Mato Grosso do Sul
# ano
# 2016            62091.42  40123.29      7740.27            11698.65
# 2017            64308.70  66078.33      5259.46            13568.51
# 2018           103036.69  79801.93     10980.07            14250.02
# 2019           141424.47  90388.47     14676.19            11292.05

# %%
type(vendas_co)
# Out:
# pandas.core.frame.DataFrame

# %%
cores = [AZUL2, AZUL3, AZUL4, CINZA3, CINZA4]

ax = vendas_co.plot(kind = 'bar', stacked = True, figsize = (10, 5), color = cores) # stacked serve para empilhar as barras
ax.set_title('Vendas por estado do Centro-Oeste de 2016 a 2019', fontsize = 14, loc = 'left', color = 'black')
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_yticklabels([])
ax.xaxis.set_tick_params(labelsize = 14, labelcolor = CINZA2, rotation = 0)
ax.set_frame_on(False)
ax.tick_params(axis = 'both', which = 'both', length = 0)
ax.legend(reverse = True, title = 'Estado', title_fontsize = 11, fontsize = 10)
for container in ax.containers:
  labels = [f'R$ {valor.get_height()/1000:,.0f}K'.replace(',', '.') for valor in container]
  ax.bar_label(container, label_type = 'center', labels = labels, size = 8, color = 'black')

# %% [markdown]
# #### Gráfico de inclinação

# %%
# importando bibliotecas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# serve para fazer com que os gráficos gerados sejam exibidos dentro do notebook

# %%
vendas_co.to_excel('venda_co.xlsx')

# %%
# Criando a figura
fig, ax = plt.subplots(figsize = (10,5))

# Criando os gráficos    index = ano
sns.lineplot(data = vendas_co, x = vendas_co.index, y = 'Distrito Federal', marker = 'o', color = 'blue', linewidth = 2)
sns.lineplot(data = vendas_co, x = vendas_co.index, y = 'Goiás', marker = 'o', color = 'grey', linewidth = 2)
sns.lineplot(data = vendas_co, x = vendas_co.index, y = 'Mato Grosso', marker = 'o', color = 'grey', linewidth = 2)
sns.lineplot(data = vendas_co, x = vendas_co.index, y = 'Mato Grosso do Sul', marker = 'o', color = 'grey', linewidth = 2)

# Adicionando título e removendo labels
plt.title('Vendas por estado do Centro-Oeste de 2016 a 2019', fontsize = 16, loc = 'left', color = 'black')
plt.xlabel('')

# Removendo o eixo y
plt.gca().axes.get_yaxis().set_visible(False)

# Removendo as bordas
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

# Definindo os limites do eixo x
plt.xticks(vendas_co.index)

# Adicionando rótulos dos estados
for estado in ['Distrito Federal', 'Goiás', 'Mato Grosso', 'Mato Grosso do Sul']:
    x = vendas_co.index[0]  # Posição inicial do eixo x
    y = vendas_co[estado].iloc[0]  # Valor inicial do estado
    # Ajustando a posição dos rótulos
    plt.annotate(estado, (x, y), textcoords="offset points", xytext=(-50, 0), ha='center', fontsize=10)

# exibindo o gráfico
plt.tight_layout()

# %% [markdown]
# ### **Desafio 2:** Analisando cada departamento, como estão divididos os modos de envio em cada um deles percentualmente?

# %%
vendas.head(1)
# Out:
#   data_pedido data_envio modo_envio     nome_cliente segmento_cliente  \
# 0  2018-11-09 2018-11-12  Econômica  Thiago Silveira              B2C
#
#            cidade     estado   regiao             departamento  tipo_produto  \
# 0  Ribeirão Preto  São Paulo  Sudeste  Materiais de construção  encanamentos
#
#    preco_base  preco_unit_sem_desc  desconto  preco_unit_venda  quantidade  \
# 0       409.7               445.33       0.0            445.33           2
#
#    vendas  lucro
# 0  890.66  71.26

# %%
# criando um dataframe com a quantidade de cada modo de envio
vendas_envio = vendas.copy()
vendas_envio = vendas_envio[['modo_envio', 'segmento_cliente']]

# criando uma nova tabela cruzada com os modos de envio somados e divididos entre cliente B2B e B2C
vendas_envio_seg = pd.crosstab(index = vendas_envio['modo_envio'], columns = vendas_envio['segmento_cliente']).sort_values('B2B')
vendas_envio_seg
# Out:
# segmento_cliente   B2B   B2C
# modo_envio
# 24 horas           207   288
# Envio rápido       676   673
# Econômica          829   906
# Entrega padrão    2552  2809

# %%
# criando uma tabela cruzada com os dados normalizados
vendas_envio_normalizado = pd.crosstab(index = vendas_envio['modo_envio'], columns = vendas_envio['segmento_cliente'], normalize = 'index')
vendas_envio_normalizado
# Out:
# segmento_cliente       B2B       B2C
# modo_envio
# 24 horas          0.418182  0.581818
# Econômica         0.477810  0.522190
# Entrega padrão    0.476031  0.523969
# Envio rápido      0.501112  0.498888

# %%
# Função para escrita de texto utilizando diferentes cores. Não existe uma
# função nativa para isso. (Adaptado de https://github.com/empathy87/storytelling-with-data)

from matplotlib import transforms

def texto_colorido(x, y, texto, cores, esp = 20, ax = None, **kw):
  cores = list(reversed(cores))
  t = ax.transData
  canvas = ax.figure.canvas

  for i, linha in enumerate(reversed(texto.split('\n'))):
    frases = linha.split('||')
    for s, cor in zip(frases, cores[i]):
      texto = ax.text(x, y, x, color = cor, transform = t, **kw)
      texto.draw(canvas.get_renderer())
      ex = texto.get_window_extent()
      t = transforms.offset_copy(texto._transform, x = ex.width, units = 'dots')

    t = transforms.offset_copy(ax.transData, x = 0, y = (i + 1) * esp, units = 'dots')

# %%
# área do gráfico
fig, axs = plt.subplots(1, 2, figsize = (15, 6), sharey = True) # sharey serve para que os dois gráficos compartilhem o mesmo eixo x
               # 1 linha para 2 gráficos

cores = [AZUL2, AZUL5]

## GRÁFICO 1
# gerando gráfico de barras horizontais empilhadas
axs[0].barh(vendas_envio_seg.index, vendas_envio_seg['B2B'], color = cores[0]) # gráfico à esquerda
axs[0].barh(vendas_envio_seg.index, vendas_envio_seg['B2C'], left = vendas_envio_seg['B2B'], color = cores[1]) # gráfico especificado que ficará à esquerda
axs[0].set_title('Em valores absolutos\n', color = CINZA2) # pulei uma linha ao final do título para aumentar o espaço entre ele e as barras
axs[0].set_xlabel('') # sem rótulos no eixo x
axs[0].set_ylabel('') # sem rótulos no eixo y
axs[0].set_xticklabels([]) # sem ticks no eixo x
axs[0].yaxis.set_tick_params(labelsize = 14, color = CINZA2)
axs[0].set_frame_on(False)

# remover todos os ticks do eixo x e y
axs[0].tick_params(axis = 'both', which = 'both', length = 0) # ambos os axis e de todos os tamanhos serão ocultados

texto_colorido(0, 3.5, '$\\bf{B2B}$ | || $\\bf{B2C}$', cores = [cores], ax = axs[0], fontsize = 12)

## GRÁFICO 2
axs[1].barh(vendas_envio_normalizado.index, vendas_envio_normalizado['B2B'], color = cores[0])
axs[1].barh(vendas_envio_normalizado.index, vendas_envio_normalizado['B2C'], left = vendas_envio_normalizado['B2B'], color = cores[1])
axs[1].set_title('Em porcentagem\n', color = CINZA2)
axs[1].set_xlabel('100%', color = CINZA2, size = 14, loc = 'right')
axs[1].set_ylabel('')
axs[1].set_xticklabels([])
axs[1].set_frame_on(False)

axs[1].tick_params(axis = 'both', which = 'both', length = 0)

texto_colorido(0, 3.5, '$\\bf{B2B}$ | || $\\bf{B2C}$', cores = [cores], ax = axs[1], fontsize = 12)

# título de ambos os gráficos (ou título de toda a figura)
fig.suptitle('Modo de envio mais utilizado pelos clientes B2B/B2C (2016-2019)\n', fontsize = 18, color = CINZA1, ha = 'right', x = 0.55, y = 1.05)

## valores das barras
for container in axs[0].containers:
  labels = [str(valor.get_width()) if valor.get_width() > 300 else '' for valor in container]
  axs[0].bar_label(container, label_type = 'center', labels = labels, size = 12, color = 'black', fontweight = 'bold')

for container in axs[1].containers:
  labels = [f'{valor.get_width() * 100:.1f}%' for valor in container]
  axs[1].bar_label(container, label_type = 'center', labels = labels, size = 12, color = 'black', fontweight = 'bold')

fig.show()

# %% [markdown]
# ## **Terceiro desafio: séries de tempo**
# ---

# %% [markdown]
# Vamos praticar a criação de gráficos de séries de tempo. Para a prática, vamos seguir utilizando o conjunto de dados do relatório de vendas das lojas de departamentos de 2016 a 2019 que está disponível no <a href = 'https://github.com/alura-cursos/dataviz-graficos/blob/master/dados/relatorio_vendas.csv'>github do projeto</a>.
#
# Neste desafio, a missão é construir as visualizações que respondam aos questionamentos que compartilharemos aqui abaixo:

# %% [markdown]
# ### **Desafio 1:** Como estão as vendas por semestre no estado em que você mora ou que deseja conhecer? Destaque os valores máximos e mínimos de venda para apresentá-los ao seu público.

# %%
vendas.query('estado == "Bahia"')[['data_pedido', 'vendas']]
# Out:
#      data_pedido   vendas
# 17    2016-08-28    29.10
# 18    2016-08-28   725.82
# 19    2016-08-28    77.24
# 20    2018-12-10    66.15
# 21    2018-12-10   205.17
# ...          ...      ...
# 8879  2018-09-05    82.53
# 8880  2018-09-05  9519.85
# 8890  2019-11-25   760.20
# 8936  2019-11-18   271.97
# 8937  2019-11-18   700.75
#
# [680 rows x 2 columns]

# %%
df_ba = vendas.copy()
df_ba = df_ba.query('estado == "Bahia"')[['data_pedido', 'vendas']]

df_ba.set_index('data_pedido', inplace = True)
df_ba = df_ba.resample('2Q', closed = 'left').sum()
df_ba = df_ba.reset_index()
df_ba
# Out:
#   data_pedido     vendas
# 0  2016-06-30   48100.19
# 1  2016-12-31   84362.51
# 2  2017-06-30   25747.57
# 3  2017-12-31   43287.77
# 4  2018-06-30   47121.96
# 5  2018-12-31   75146.47
# 6  2019-06-30   59364.91
# 7  2019-12-31  101422.00

# %%
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize = (16, 4))

venda_min = df_ba['vendas'].min()
venda_max = df_ba['vendas'].max()
valores = df_ba['vendas'].values

pontos_marcar = list((valores == venda_min) | (valores == venda_max))

ax.plot(df_ba['data_pedido'], df_ba['vendas'], lw = 3, color = AZUL3, marker = 'o', markersize = 10, markerfacecolor = AZUL1, markevery = pontos_marcar)

ax.set_title('Vendas no estado da Bahia (2016-2019)', fontsize = 16, loc = 'left', pad = 20)
ax.set_xlabel('Meses', fontsize = 14)
ax.set_ylabel('')
ax.grid(axis = 'y', linestyle = '--')
ax.set_frame_on(False)

ax.tick_params(axis = 'both', which = 'both', length = 0)

plt.ylim(0, 1.25e5)

ax.xaxis.set_major_locator(mdates.MonthLocator(bymonth = [6, 12]))

labels = ["1º Sem, 2016", "2º Sem, 2016", "1º Sem, 2017", "2º Sem, 2017",
          "1º Sem, 2018", "2º Sem, 2018", "1º Sem, 2019", "2º Sem, 2019"]
ax.set_xticks(ax.get_xticks())
ax.set_xticklabels(labels, ha = 'left')

for x, y in zip(df_ba['data_pedido'], df_ba['vendas']):
  if y == venda_min:
    ax.text(x, y = y - 1.2e4, s = f'  O 1º Semestre de 2017 registrou \n  a única vendas abaixo de R$ 40 mil.', fontsize = 10)
  if y == venda_max:
    ax.text(x, y = y - 1.2e4, s = f'  As vendas ultrapassaram \n  pela 1ª vez a faixa \n  de R$ 100 mil \n  no 2º Semestre de 2019', fontsize = 10)

plt.show()

# %% [markdown]
# ### **Desafio 2:** Compare os lucros anuais dos estados da região Nordeste por meio de um gráfico de linhas.

# %%
# Importando as bibliotecas
import pandas as pd
import plotly.express as px

# Importando o relatório de vendas e atualizando a colunas de pedido para o tipo data
vendas = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/dataviz-graficos/master/dados/relatorio_vendas.csv")
vendas["data_pedido"] = pd.to_datetime(vendas["data_pedido"], format="%Y-%m-%d")

# Criando um df com os dados desejados
df_ne = vendas.copy()
df_ne = df_ne.query("regiao == 'Nordeste'")[["estado","data_pedido", "lucro"]]

# %%
# Criando uma tabela cruzada (crosstab) com os valores de lucro por dia por estado
df_estados_ne = pd.crosstab(index = df_ne.data_pedido, columns = df_ne.estado, values = df_ne.lucro, aggfunc="sum")

# Agrupando os lucros por ano
df_estados_ne = df_estados_ne.resample('Y').agg('sum')
df_estados_ne = round(df_estados_ne/1e3, 2)
df_estados_ne
# Out:
# estado       Alagoas  Bahia  Ceará  Maranhão  Paraíba  Pernambuco  Piauí  \
# data_pedido
# 2016-12-31      1.20   9.98  10.25      1.88    -0.27       11.73   0.02
# 2017-12-31      3.77   6.89   9.88      1.60    -2.20        4.24   1.43
# 2018-12-31      3.13   8.59   6.40      2.69     0.15        9.18   5.43
# 2019-12-31      1.45  14.09  30.26      5.07     1.60        6.98   1.34
#
# estado       Rio Grande do Norte  Sergipe
# data_pedido
# 2016-12-31                  0.27     0.89
# 2017-12-31                  0.65     0.98
# 2018-12-31                  1.44     0.55
# 2019-12-31                  2.09     1.95

# %%
# Importando a biblioteca
import plotly.express as px

# Gerando um gráfico de linha com os lurcos das lojas por ano dividido por estado da região nordeste
fig = px.line(df_estados_ne, x=df_estados_ne.index, y=df_estados_ne.columns, markers = True, labels={"estado": "Estados"},
              color_discrete_sequence=[AZUL2, VERMELHO1, AMARELO1 , VERDE1, CINZA3, AZUL5, LARANJA1, CINZA1, AZUL4])

# Ajustando o layout do gráfico
fig.update_layout(width=1300, height=600, font_family = 'DejaVu Sans', font_size=15,
                  font_color= CINZA2, title_font_color= CINZA1, title_font_size=24,
                  title_text='Lucros das lojas de departamentos por ano na Região Nordeste' +
                             '<br><sup size=1 style="color:#555655">De 2016 a 2019</sup>',
                  xaxis_title='', yaxis_title='', plot_bgcolor= CINZA5)

# Ajustando os ticks do eixo y para o formato em milhar
fig.update_yaxes(tickprefix="R$ ", ticksuffix=" mil")

# Ajustando o eixo x com os labels dos anos
labels = ['2016', '2017', '2018', '2019']
fig.update_xaxes(ticktext = labels, tickvals=df_estados_ne.index)

# Dados ao passar o mouse (hover)
fig.update_traces(mode="markers+lines", hovertemplate = "<b>Período:</b> %{x} <br> <b>Lucro:</b> %{y}")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Quarto desafio: distribuindo dados**
# ---

# %% [markdown]
# Vamos praticar a criação de gráficos de distribuição de dados. Para esse desafio, vamos trabalhar com duas base de dados diferentes: a primeira será um <a href = "https://caelum-online-public.s3.amazonaws.com/3057-data-visualization/Atividades/Aula+04/pop_idade.csv">dataset com as idades de uma amostra da população do município de Cidade Alegre</a>, cidade fictícia que utilizamos em uma de nossas atividades, e a segunda será o dataset dos volumes do amaciante que utilizamos durante essa aula, que está disponível no <a href = "https://github.com/alura-cursos/dataviz-graficos/blob/master/dados/volume_amaciante.csv">github do projeto</a>.
#
# Neste desafio, a missão é construir as visualizações que respondam aos questionamentos que compartilharemos aqui abaixo:

# %% [markdown]
# #### **Desafio 1:** Baixe a base de dados com as amostras das idades dos moradores do município de Cidade Alegre e crie os histogramas de colunas e de linha lado a lado, buscando interpretar as diferenças entre eles e o que podem representar separadamente. Adicione também uma linha que define a mediana da distribuição no histograma de linha e escreva o valor dessa medida no gráfico.

# %%
url = '/content/drive/MyDrive/Data Science/Data Visualization/Gráf.de comp.e distr/pop_idade.csv'
dados = pd.read_csv(url)
dados
# Out:
#      idade
# 0       39
# 1       33
# 2       41
# 3       50
# 4       32
# ..     ...
# 495     40
# 496     24
# 497     33
# 498     26
# 499     21
#
# [500 rows x 1 columns]

# %%
fig, axs = plt.subplots(1,2, figsize = (15,6))
sns.set_theme(style = 'white')

fig.suptitle('Distribuição da idade da população de Cidade Alegre \npara uma amostra de 500 pessoas',
             fontsize = 18, color = CINZA1, x = 0.1, y = 1.05, ha = 'left')

sns.histplot(ax = axs[0], data = dados, x = 'idade', binwidth = 5, color = AZUL2)
axs[0].set_title('Distribuição para um intervalo de 5 anos', size = 14, color = CINZA1, x = 0.35, pad = 10)
axs[0].set_xlabel('Idade', fontsize = 14)
axs[0].set_ylabel('Quantidade', fontsize = 14)
axs[0].yaxis.set_tick_params(labelsize = 12, labelcolor = CINZA2)
axs[0].xaxis.set_tick_params(labelsize = 12, labelcolor = CINZA2)
sns.despine()

sns.kdeplot(ax = axs[1], data = dados, x = 'idade', color = AZUL2)
axs[1].set_title('Visualizando as medidas de tendência central', size = 14, color = CINZA1, x = 0.35, pad = 10)
axs[1].set_xlabel('Idade', fontsize = 14)
axs[1].set_ylabel('')
axs[1].yaxis.set_tick_params(labelsize = 12, labelcolor = CINZA2)
axs[1].set_yticklabels([])
sns.despine()

# gerando linha que define a mediana e anotando seu valor
axs[1].vlines(x = dados.idade.median(), ymin = 0, ymax = 0.04, colors = CINZA2, linestyles = '--')
axs[1].text(0.6, 0.6, f'Mediana = {int(dados.idade.median())} anos', fontsize = 14, color = CINZA2, transform = axs[1].transAxes)

plt.show()

# %% [markdown]
# ### **Desafio 2:** Represente no boxplot dos volumes do amaciante os limites superiores e inferiores do diagrama de caixa. Comente sobre o resultado encontrado ao desenhar esses limites no boxplot.

# %%
url = '/content/drive/MyDrive/Data Science/Data Visualization/Gráf.de comp.e distr/volume_amaciante.csv'
vol_amaciante = pd.read_csv(url)
vol_amaciante
# Out:
#      Volume
# 0     999.8
# 1     999.5
# 2     999.7
# 3     999.1
# 4     999.8
# ..      ...
# 995  1000.0
# 996  1000.4
# 997   999.9
# 998  1000.0
# 999  1000.5
#
# [1000 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize = (6, 8))
sns.set_theme(style = 'white')

ax = sns.boxplot(data = vol_amaciante, y = 'Volume', orient = 'v', color = AZUL2)
plt.suptitle('Boxplot do volume do amaciante', size = 18, color = CINZA1, ha = 'right', x = 0.81, y = 0.97)
plt.title('para uma amostra de 1000 unidades', fontsize = 14, color = CINZA2, pad = 15, loc = 'left')
ax.set_xlabel('')
ax.set_ylabel('Volume (ml)', fontsize = 14)
ax.yaxis.set_tick_params(labelsize = 12, labelcolor = CINZA2)
sns.despine(bottom = True)

IIQ = vol_amaciante['Volume'].quantile(0.75) - vol_amaciante['Volume'].quantile(0.25)
limite_superior = vol_amaciante['Volume'].quantile(0.75) + 1.5 * IIQ
limite_inferior = vol_amaciante['Volume'].quantile(0.25) - 1.5 * IIQ

ax.annotate('Limite Superior', xy = (0, limite_superior), xycoords = 'data',# coordenadas do ponto desejado
            bbox=dict(boxstyle="round", fc=CINZA5, ec=CINZA2),                          # caixa de texto
            xytext=(50, 0), textcoords='offset points',                                 # posição do texto
            arrowprops=dict(arrowstyle="->", color=CINZA2))                             # propriedades da seta)

ax.annotate("Limite Inferior", xy=(0, limite_inferior), xycoords='data',
            bbox=dict(boxstyle="round", fc=CINZA5, ec=CINZA2),
            xytext=(50, 0), textcoords='offset points',
            arrowprops=dict(arrowstyle="->", color=CINZA2))

plt.show()

# %% [markdown]
# ## **Quinto desafio: explorando padrões nos dados**
# ---

# %% [markdown]
# Vamos praticar a criação de gráficos de distribuição de dados para duas variáveis, numéricas e/ou categóricas. Para a prática, vamos trabalhar com duas base de dados diferentes: a primeira será um <a href = 'https://caelum-online-public.s3.amazonaws.com/3057-data-visualization/Atividades/Aula+05/notas.csv'>dataset com as notas de 3 turmas do curso de Data Visualization</a> da plataforma de cursos de tecnologia fictícia que utilizamos em uma de nossas atividades, e a segunda será o dataset das medidas da caixa de sabão em pó da fábrica de produtos de higiene e limpeza que utilizamos durante essa aula, que está disponível no <a href = 'https://github.com/alura-cursos/dataviz-graficos/blob/master/dados/medidas_sabao_em_po.csv'>github do projeto</a>.
#
# Neste desafio, a missão é construir as visualizações que respondam aos questionamentos que compartilharemos aqui abaixo:

# %% [markdown]
# #### **Desafio 1:** Baixe a base de dados com as notas das turmas de Data Visualization e crie o violinplot, buscando interpretar as diferenças entre cada uma delas e documentando os seus achados. Sinta-se livre para adicionar alguns dos recursos que aprendemos ao longo do curso, como anotações, textos e figuras.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

notas = pd.read_csv("/content/drive/MyDrive/Data Science/Data Visualization/Gráf.de comp.e distr/notas.csv")
notas.head()
# Out:
#      Turma  Nota
# 0  Turma 1    79
# 1  Turma 1    73
# 2  Turma 1    80
# 3  Turma 1    88
# 4  Turma 1    72

# %%
# Área do gráfico e tema da visualização
fig, ax = plt.subplots(figsize=(10,5))
fig.subplots_adjust(right = 0.7)
sns.set_theme(style="whitegrid")

# Gerando o violinplot das notas
ax = sns.violinplot(data = notas, x = "Turma", y = "Nota", palette = "vlag_r")

# Personalizando o gráfico
plt.suptitle('Distribuição das notas das turmas de Data Visualization\n(100 alunos cada)', size=18, color=CINZA1, ha = 'left', x = 0.1, y = 1.05)
ax.set_xlabel('')
ax.set_ylabel('Notas (0-100)', fontsize = 14)
ax.xaxis.set_tick_params(labelsize=12, labelcolor = CINZA2)
ax.yaxis.set_tick_params(labelsize=12, labelcolor = CINZA2)
sns.despine(bottom=True)

# Criando uma lista com as medianas de cada turma
mediana = []
for i in range(1,4):
  mediana.append(notas.query(f"Turma == 'Turma {i}'").Nota.median())

# Texto explicativo
ax.text(2.6, 60,
         'O gráfico acima mostra a distribuição dos valores entre\n'
         'três turmas do curso de Dataviz: $\\bf{Turma\ 1}$, $\\bf{Turma\ 2}$ e $\\bf{Turma\ 3}$.\n\n'
         'A $\\bf{Turma\ 1}$ apresenta uma distribuição aproximadamente normal,\n'
         f'com a mediana de {mediana[0]} e uma variabilidade moderada.\n\n'
         ' A $\\bf{Turma\ 2}$ mostra uma distribuição mais estreita, com a mediana\n'
         f'de {mediana[1]} e uma variabilidade menor.\n\n'
         'Enquanto isso, a $\\bf{Turma\ 3}$ possui uma distribuição mais assimétrica,\n'
         f'com a mediana de {mediana[2]} e uma variabilidade maior em relação aos outros grupos.',
         fontsize=10, linespacing=1.45, color=CINZA2)

plt.show()

# %% [markdown]
# #### **Desafio 2:** Crie o gráfico de dispersão que distribua as medidas de comprimento e largura da amostra B. Desenhe no gráfico as linhas de rejeição para os itens em que o valor de comprimento e largura seja acima de 2% ou abaixo do valor de 20 cm e 5 cm, respectivamente.

# %%
# Importando a base de dados dos volumes de um amaciante em 1000 amostras realizadas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_medidas = pd.read_csv("https://raw.githubusercontent.com/afonsosr2/dataviz-graficos/master/dados/medidas_sabao_em_po.csv")
df_b = df_medidas.query('amostra == "B"')[["comprimento", "largura"]]

df_b.head()
# Out:
#      comprimento  largura
# 200        19.97     5.10
# 201        20.13     4.94
# 202        20.12     4.95
# 203        20.04     4.96
# 204        19.97     4.98

# %%
# Área do gráfico e tema da visualização
fig, ax = plt.subplots(figsize=(10,5))
sns.set_theme(style="white")

# Definindo as cores do gráfico e a porcentagem de rejeição
cores = [VERMELHO1, LARANJA1, AZUL2]
pct = 0.02

# Mapeando as cores para a faixa requisitada (2%)
rejeita_comp = [True if (c > 20*(1+pct) or c < 20*(1-pct)) else False for c in df_b["comprimento"]]
rejeita_larg = [True if (a > 5*(1+pct) or a < 5*(1-pct)) else False for a in df_b["largura"]]
map_cores = np.where(rejeita_comp, cores[0], np.where(rejeita_larg, cores[1], cores[2]))

# Gerando o gráfico de dispersão
ax = sns.scatterplot(data = df_b, x="comprimento", y = "largura", color = map_cores)

# Personalizando o gráfico
plt.suptitle('Distribuição das medidas da caixa de sabão em pó (amostra B de 200 registros)', size=14, color=CINZA1, ha = 'right', x = 0.9, y = 1)
ax.set_xlabel('Comprimento (cm)', fontsize = 12)
ax.set_ylabel('Largura (cm)', fontsize = 12)
ax.yaxis.set_tick_params(labelsize=10, labelcolor = CINZA2)
ax.xaxis.set_tick_params(labelsize=10, labelcolor = CINZA2)
sns.despine()

### Desenhando as linhas verticais com os limites mínimos e máximo de altura desejada
ax.text(20.15, 5.1, 'Limite máximo de largura', fontsize=12, color = CINZA2, ha="left", va = "bottom")
plt.axhline(y = 5 * (1 + pct), color = CINZA4, linestyle='--')
ax.text(20.15, 4.9, 'Limite mínimo de largura', fontsize=12, color = CINZA2, ha="left", va = "top")
plt.axhline(y = 5 * (1 - pct), color = CINZA4, linestyle='--')

plt.show()
